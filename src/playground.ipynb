# %%
import train
import env_hiv
env = env_hiv.HIVPatient(domain_randomization=True)
agent = train.ProjectAgent(env)
agent.train()
# Out:
# (16_w,33)-aCMA-ES (mu_w=9.4,w_1=19%) in dimension 17924 (seed=123, Wed Feb 21 22:27:41 2024)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     25 -2.890643450242555e+09 1.0e+00 9.99e-02  1e-01  1e-01 0:14.5
#     2     50 -2.130725243030025e+09 1.0e+00 9.99e-02  1e-01  1e-01 0:26.0
#     3     75 -2.016675836281715e+09 1.0e+00 9.98e-02  1e-01  1e-01 0:37.4
#     4    100 -2.368194579674098e+09 1.0e+00 9.98e-02  1e-01  1e-01 0:48.8
#     5    125 -3.565681593745776e+09 1.0e+00 9.97e-02  1e-01  1e-01 1:00.2
#     6    150 -3.233130633676500e+09 1.0e+00 9.96e-02  1e-01  1e-01 1:11.7
#     7    175 -3.634342911737335e+09 1.0e+00 9.96e-02  1e-01  1e-01 1:23.2
#     8    200 -3.052525719864229e+09 1.0e+00 9.95e-02  1e-01  1e-01 1:34.8
#     9    225 -3.769271009986713e+09 1.0e+00 9.95e-02  1e-01  1e-01 1:46.2
#    10    250 -3.747541886926562e+09 1.0e+00 9.94e-02  1e-01  1e-01 1:57.6
# ...

# %%
agent.save()
agent.load()
