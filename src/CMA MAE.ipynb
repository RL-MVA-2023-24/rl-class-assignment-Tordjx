# %%
# !export PYTHONWARNINGS="default"

# %%
a=9709249010.93793
b=2610906993.0028586
print('indiv',"{:e}".format(a),end = "\n")
print('pop',"{:e}".format(b),end = "\n")
# Out:
# indiv 9.709249e+09
# pop 2.610907e+09

# %%
# %pip install swig  # Must be installed before box2d.
# %pip install ribs[visualize] gymnasium[box2d]==0.29.1 "moviepy>=1.0.0" dask distributed

import importlib
import decorator
importlib.reload(decorator)
# Out:
# Requirement already satisfied: swig in /opt/mamba/lib/python3.11/site-packages (4.2.0.post0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium==0.29.1 in /opt/mamba/lib/python3.11/site-packages (from gymnasium[box2d]==0.29.1) (0.29.1)
# Requirement already satisfied: moviepy>=1.0.0 in /opt/mamba/lib/python3.11/site-packages (1.0.3)
# Requirement already satisfied: dask in /opt/mamba/lib/python3.11/site-packages (2024.2.1)
# Requirement already satisfied: distributed in /opt/mamba/lib/python3.11/site-packages (2024.2.1)
# Requirement already satisfied: ribs[visualize] in /opt/mamba/lib/python3.11/site-packages (0.7.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/mamba/lib/python3.11/site-packages (from gymnasium==0.29.1->gymnasium[box2d]==0.29.1) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/mamba/lib/python3.11/site-packages (from gymnasium==0.29.1->gymnasium[box2d]==0.29.1) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/mamba/lib/python3.11/site-packages (from gymnasium==0.29.1->gymnasium[box2d]==0.29.1) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/mamba/lib/python3.11/site-packages (from gymnasium==0.29.1->gymnasium[box2d]==0.29.1) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /opt/mamba/lib/python3.11/site-packages (from gymnasium[box2d]==0.29.1) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /opt/mamba/lib/python3.11/site-packages (from gymnasium[box2d]==0.29.1) (2.5.2)
# Requirement already satisfied: swig==4.* in /opt/mamba/lib/python3.11/site-packages (from gymnasium[box2d]==0.29.1) (4.2.0.post0)
# Requirement already satisfied: numpy-groupies>=0.9.16 in /opt/mamba/lib/python3.11/site-packages (from ribs[visualize]) (0.10.2)
# Requirement already satisfied: numba>=0.51.0 in /opt/mamba/lib/python3.11/site-packages (from ribs[visualize]) (0.59.0)
# Requirement already satisfied: pandas>=1.0.0 in /opt/mamba/lib/python3.11/site-packages (from ribs[visualize]) (2.2.1)
# Requirement already satisfied: sortedcontainers>=2.0.0 in /opt/mamba/lib/python3.11/site-packages (from ribs[visualize]) (2.4.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /opt/mamba/lib/python3.11/site-packages (from ribs[visualize]) (1.4.1.post1)
# Requirement already satisfied: scipy>=1.7.0 in /opt/mamba/lib/python3.11/site-packages (from ribs[visualize]) (1.12.0)
# Requirement already satisfied: threadpoolctl>=3.0.0 in /opt/mamba/lib/python3.11/site-packages (from ribs[visualize]) (3.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/mamba/lib/python3.11/site-packages (from ribs[visualize]) (3.8.3)
# Requirement already satisfied: shapely>=2.0.0 in /opt/mamba/lib/python3.11/site-packages (from ribs[visualize]) (2.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /opt/mamba/lib/python3.11/site-packages (from moviepy>=1.0.0) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /opt/mamba/lib/python3.11/site-packages (from moviepy>=1.0.0) (4.66.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /opt/mamba/lib/python3.11/site-packages (from moviepy>=1.0.0) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /opt/mamba/lib/python3.11/site-packages (from moviepy>=1.0.0) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /opt/mamba/lib/python3.11/site-packages (from moviepy>=1.0.0) (2.34.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /opt/mamba/lib/python3.11/site-packages (from moviepy>=1.0.0) (0.4.9)
# Requirement already satisfied: click>=8.1 in /opt/mamba/lib/python3.11/site-packages (from dask) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/mamba/lib/python3.11/site-packages (from dask) (2024.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/mamba/lib/python3.11/site-packages (from dask) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /opt/mamba/lib/python3.11/site-packages (from dask) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/mamba/lib/python3.11/site-packages (from dask) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /opt/mamba/lib/python3.11/site-packages (from dask) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/mamba/lib/python3.11/site-packages (from dask) (7.0.1)
# Requirement already satisfied: jinja2>=2.10.3 in /opt/mamba/lib/python3.11/site-packages (from distributed) (3.1.3)
# Requirement already satisfied: locket>=1.0.0 in /opt/mamba/lib/python3.11/site-packages (from distributed) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /opt/mamba/lib/python3.11/site-packages (from distributed) (1.0.7)
# Requirement already satisfied: psutil>=5.7.2 in /opt/mamba/lib/python3.11/site-packages (from distributed) (5.9.8)
# Requirement already satisfied: tblib>=1.6.0 in /opt/mamba/lib/python3.11/site-packages (from distributed) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /opt/mamba/lib/python3.11/site-packages (from distributed) (6.3.3)
# Requirement already satisfied: urllib3>=1.24.3 in /opt/mamba/lib/python3.11/site-packages (from distributed) (1.26.18)
# Requirement already satisfied: zict>=3.0.0 in /opt/mamba/lib/python3.11/site-packages (from distributed) (3.0.0)
# Requirement already satisfied: pillow>=8.3.2 in /opt/mamba/lib/python3.11/site-packages (from imageio<3.0,>=2.5->moviepy>=1.0.0) (10.2.0)
# Requirement already satisfied: setuptools in /opt/mamba/lib/python3.11/site-packages (from imageio-ffmpeg>=0.2.0->moviepy>=1.0.0) (68.2.2)
# Requirement already satisfied: zipp>=0.5 in /opt/mamba/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/mamba/lib/python3.11/site-packages (from jinja2>=2.10.3->distributed) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib>=3.0.0->ribs[visualize]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/mamba/lib/python3.11/site-packages (from matplotlib>=3.0.0->ribs[visualize]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/mamba/lib/python3.11/site-packages (from matplotlib>=3.0.0->ribs[visualize]) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib>=3.0.0->ribs[visualize]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib>=3.0.0->ribs[visualize]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/mamba/lib/python3.11/site-packages (from matplotlib>=3.0.0->ribs[visualize]) (2.8.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/mamba/lib/python3.11/site-packages (from numba>=0.51.0->ribs[visualize]) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/mamba/lib/python3.11/site-packages (from pandas>=1.0.0->ribs[visualize]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/mamba/lib/python3.11/site-packages (from pandas>=1.0.0->ribs[visualize]) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/mamba/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/mamba/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/mamba/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/mamba/lib/python3.11/site-packages (from scikit-learn>=1.1.0->ribs[visualize]) (1.3.2)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->ribs[visualize]) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# <module 'decorator' from '/opt/mamba/lib/python3.11/site-packages/decorator.py'>

# %%
from env_hiv import HIVPatient
import numpy as np
import torch
import torch.nn as nn
from ribs.archives import GridArchive
from ribs.emitters import EvolutionStrategyEmitter
from ribs.schedulers import Scheduler
import time
from dask.distributed import Client
from tqdm import trange,tqdm
import sys
import gymnasium as gym
from gymnasium.wrappers import TimeLimit
class Policy(nn.Module) :
    def __init__(self,state_n,action_n,hsize = 32) :
        super().__init__()
        self.fc1= nn.Linear(state_n, hsize)
        self.fc2= nn.Linear(hsize, hsize)
        self.fc3= nn.Linear(hsize, action_n)
    def forward(self,x) : 
        x= torch.Tensor(x)
        if len(x.shape)==1 :
            x= x.unsqueeze(0)
        x = nn.ReLU()(self.fc1(x))
        x = nn.ReLU()(self.fc2(x))
        return nn.ReLU()(self.fc3(x))
    def get_action(self,x) :
        logits = nn.Softmax(dim=1)(self.forward(x))
        return torch.argmax(logits, dim=1).item()
    def get_params(self):
        p = np.empty((0,))
        for n in self.parameters():
            p = np.append(p, n.flatten().cpu().detach().numpy())
        return p
    def set_params(self, x):
        start = 0
        for p in self.parameters():
            e = start + np.prod(p.shape)
            p.data = torch.FloatTensor(x[start:e]).reshape(p.shape)
            start = e

# %%
def simulate(model, periode_echantillonage,seed=None):
    domain_randomization = False#np.random.binomial(1,0.5)
    env = HIVPatient(clipping=True, domain_randomization=domain_randomization)
    env = TimeLimit(env,200)
    policy = Policy(state_n=env.observation_space.shape[0] , action_n=env.action_space.n)
    policy.set_params(model)
    total_reward = 0
    states = [[] for t in range(6)]
    s,_ = env.reset(seed=seed)
    s = np.log(s+1e-9)
    done = False 
    it =0
    while not done :
        
        action = policy.get_action(s)  # Linear policy.
        s, reward, terminated, truncated, _ = env.step(action)
        s = np.log(s+1e-9)
        done = terminated or truncated
        total_reward+=reward
        if it%periode_echantillonage ==0 :
            for i,a in enumerate(s) : 
                states[i].append(a)
        it+=1
    traj = []
    for i in range(len(states)): 
        traj.append(np.mean(states[i]))
    return total_reward, traj

# %%
env = HIVPatient(clipping=True, domain_randomization=False)
periode_echantillonage =1
#env= gym.make("Acrobot")

env = TimeLimit(env,200)
ranges = list(zip(env.lower, env.upper))
for i in range(len(ranges)) :
    a,b = ranges[i]
    ranges[i] = (np.log(a+1e-9), np.log(b+1e-9))
policy = Policy(env.observation_space.shape[0] , env.action_space.n)
solution_dim=len(policy.get_params())
dims = [30 for i in range(len(ranges))]
env_seed=  None
archive = GridArchive(
    solution_dim=solution_dim,
    dims=dims,
    ranges=ranges,
    qd_score_offset=0,
    learning_rate = 0.01,
    threshold_min =0
)
result_archive = GridArchive(solution_dim=solution_dim,
                             dims=dims,
                             ranges=ranges)
emitters = [
    EvolutionStrategyEmitter(
        archive,
        x0=policy.get_params(),
        sigma0=0.5,
        ranker="imp",
        selection_rule="mu",
        restart_rule="basic",
        batch_size = 32,
    ) for _ in range(5)
]
scheduler = Scheduler(archive, emitters, result_archive=result_archive)

start_time = time.time()
total_itrs = 450
workers = 128  # Adjust the number of workers based on your available CPUs.

client = Client(
    n_workers=workers,  # Create this many worker processes using Dask LocalCluster.
    threads_per_worker=1,  # Each worker process is single-threaded.
)

for itr in trange(1, total_itrs + 1, file=sys.stdout, desc='Iterations'):
    # Request models from the scheduler.
    sols = scheduler.ask()

    # Evaluate the models and record the objectives and measuress.
    futures = client.map(lambda model: simulate(model,periode_echantillonage, env_seed), sols)
    results = client.gather(futures)
    
    objs , meas = [],[]
    for obj, traj in results :
        objs.append(obj)
        meas.append(traj)
    # Send the results back to the scheduler.
    scheduler.tell(objs, meas)

    # Logging.
    if itr % 1 == 0:
        tqdm.write(f"> {itr} itrs completed after {time.time() - start_time:.2f}s")
        tqdm.write(f"  - Size: {archive.stats.num_elites}")    # Number of elites in the archive. len(archive) also provides this info.
        tqdm.write(f"  - Coverage: {archive.stats.coverage}")  # Proportion of archive cells which have an elite.
        tqdm.write(f"  - QD Score: {archive.stats.qd_score}")  # QD score, i.e. sum of objective values of all elites in the archive.
                                                               # Accounts for qd_score_offset as described in the GridArchive section.
        objmax = "{:e}".format(archive.stats.obj_max)
        objmean  = "{:e}".format(archive.stats.obj_mean)
        tqdm.write(f"  - Max Obj: {objmax}")    # Maximum objective value in the archive.
        tqdm.write(f"  - Mean Obj: {objmean}")  # Mean objective value of elites in the archive.
# Out:
# /opt/mamba/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.lower to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.lower` for environment variables or `env.get_wrapper_attr('lower')` that will search the reminding wrappers.
#   logger.warn(
# /opt/mamba/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.upper to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.upper` for environment variables or `env.get_wrapper_attr('upper')` that will search the reminding wrappers.
#   logger.warn(
# > 1 itrs completed after 102.69s
#   - Size: 14
#   - Coverage: 1.9204389574759946e-08
#   - QD Score: 159954596.92118236
#   - Max Obj: 3.115946e+07
#   - Mean Obj: 1.142533e+07
# > 2 itrs completed after 185.35s
#   - Size: 19
#   - Coverage: 2.6063100137174212e-08
#   - QD Score: 170467739.90372968
#   - Max Obj: 3.115946e+07
#   - Mean Obj: 8.971986e+06
# > 3 itrs completed after 262.29s
#   - Size: 22
#   - Coverage: 3.017832647462277e-08
#   - QD Score: 174954208.08611214
#   - Max Obj: 3.115946e+07
#   - Mean Obj: 7.952464e+06
# > 4 itrs completed after 339.35s
#   - Size: 26
#   - Coverage: 3.5665294924554187e-08
#   - QD Score: 268107501.5063006
#   - Max Obj: 3.854641e+07
#   - Mean Obj: 1.031183e+07
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.428984e+07
# > 46 itrs completed after 3702.55s
#   - Size: 71
#   - Coverage: 9.739368998628258e-08
#   - QD Score: 2420285460.2397456
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.408853e+07
# > 47 itrs completed after 3784.46s
#   - Size: 73
#   - Coverage: 1.0013717421124828e-07
#   - QD Score: 2540769683.7317486
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.480506e+07
# > 48 itrs completed after 3869.12s
#   - Size: 74
#   - Coverage: 1.0150891632373113e-07
#   - QD Score: 2533300525.8911777
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.423379e+07
# > 49 itrs completed after 3954.22s
#   - Size: 75
#   - Coverage: 1.02880658436214e-07
#   - QD Score: 2591885017.900883
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.455847e+07
# > 50 itrs completed after 4034.71s
#   - Size: 76
#   - Coverage: 1.0425240054869685e-07
#   - QD Score: 2653778970.028348
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.491814e+07
# > 51 itrs completed after 4113.11s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2680172199.3965974
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.436118e+07
# > 52 itrs completed after 4195.16s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2609548892.0049896
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.345576e+07
# > 53 itrs completed after 4277.22s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2606222154.882539
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.341310e+07
# > 54 itrs completed after 4354.92s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2648062040.8508177
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.394951e+07
# > 55 itrs completed after 4435.79s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2683464729.9521623
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.440339e+07
# > 56 itrs completed after 4515.48s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2632857508.3893867
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.375458e+07
# > 57 itrs completed after 4593.83s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2642752763.9864087
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.388145e+07
# > 58 itrs completed after 4670.08s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2641775844.20278
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.386892e+07
# > 59 itrs completed after 4747.04s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2734253013.37906
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.505453e+07
# > 60 itrs completed after 4825.46s
#   - Size: 78
#   - Coverage: 1.0699588477366255e-07
#   - QD Score: 2748560905.7237506
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.523796e+07
# > 61 itrs completed after 4904.77s
#   - Size: 80
#   - Coverage: 1.0973936899862826e-07
#   - QD Score: 2697749462.9155936
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.372187e+07
# > 62 itrs completed after 4975.32s
#   - Size: 80
#   - Coverage: 1.0973936899862826e-07
#   - QD Score: 2685907516.308826
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.357384e+07
# > 63 itrs completed after 5048.25s
#   - Size: 80
#   - Coverage: 1.0973936899862826e-07
#   - QD Score: 2660649980.449137
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.325812e+07
# > 64 itrs completed after 5129.39s
#   - Size: 81
#   - Coverage: 1.1111111111111111e-07
#   - QD Score: 2784564803.7084913
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.437734e+07
# > 65 itrs completed after 5210.50s
#   - Size: 81
#   - Coverage: 1.1111111111111111e-07
#   - QD Score: 2860233933.728835
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.531153e+07
# > 66 itrs completed after 5288.77s
#   - Size: 82
#   - Coverage: 1.1248285322359396e-07
#   - QD Score: 2830660834.12796
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.452025e+07
# > 67 itrs completed after 5365.52s
#   - Size: 82
#   - Coverage: 1.1248285322359396e-07
#   - QD Score: 2822108303.367459
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.441595e+07
# > 68 itrs completed after 5439.83s
#   - Size: 82
#   - Coverage: 1.1248285322359396e-07
#   - QD Score: 2807373951.889419
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.423627e+07
# > 69 itrs completed after 5520.51s
#   - Size: 83
#   - Coverage: 1.1385459533607682e-07
#   - QD Score: 2828562539.1924586
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.407907e+07
# > 70 itrs completed after 5600.12s
#   - Size: 83
#   - Coverage: 1.1385459533607682e-07
#   - QD Score: 2760674097.0574503
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.326113e+07
# > 71 itrs completed after 5679.26s
#   - Size: 84
#   - Coverage: 1.1522633744855967e-07
#   - QD Score: 2846448731.1172633
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.388629e+07
# > 72 itrs completed after 5761.12s
#   - Size: 85
#   - Coverage: 1.1659807956104252e-07
#   - QD Score: 2852524530.497112
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.355911e+07
# > 73 itrs completed after 5842.17s
#   - Size: 85
#   - Coverage: 1.1659807956104252e-07
#   - QD Score: 2851697084.0904765
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.354938e+07
# > 74 itrs completed after 5932.62s
#   - Size: 85
#   - Coverage: 1.1659807956104252e-07
#   - QD Score: 2863730459.6424346
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.369095e+07
# > 75 itrs completed after 6015.90s
#   - Size: 85
#   - Coverage: 1.1659807956104252e-07
#   - QD Score: 2962453267.072071
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.485239e+07
# > 76 itrs completed after 6092.37s
#   - Size: 85
#   - Coverage: 1.1659807956104252e-07
#   - QD Score: 2934573065.5849137
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.452439e+07
# > 77 itrs completed after 6169.42s
#   - Size: 86
#   - Coverage: 1.1796982167352537e-07
#   - QD Score: 2954802741.4879355
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.435817e+07
# > 78 itrs completed after 6251.30s
#   - Size: 88
#   - Coverage: 1.2071330589849107e-07
#   - QD Score: 2959609397.2438736
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.363192e+07
# > 79 itrs completed after 6325.39s
#   - Size: 88
#   - Coverage: 1.2071330589849107e-07
#   - QD Score: 2992479148.904197
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.400544e+07
# > 80 itrs completed after 6406.27s
#   - Size: 90
#   - Coverage: 1.234567901234568e-07
#   - QD Score: 3018268539.9539104
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.353632e+07
# > 81 itrs completed after 6494.72s
#   - Size: 91
#   - Coverage: 1.2482853223593963e-07
#   - QD Score: 3047904515.8441195
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.349346e+07
# > 82 itrs completed after 6571.01s
#   - Size: 91
#   - Coverage: 1.2482853223593963e-07
#   - QD Score: 3028358129.461929
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.327866e+07
# > 83 itrs completed after 6645.84s
#   - Size: 91
#   - Coverage: 1.2482853223593963e-07
#   - QD Score: 3090042704.2411523
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3.395651e+07
# > 84 itrs completed after 6725.30s
#   - Size: 92
#   - Coverage: 1.262002743484225e-07
#   - QD Score: 3094958206.8961396
#   - Max Obj: 9.296764e+08
#   - Mean Obj: 3
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.183401e+08
# > 106 itrs completed after 8514.02s
#   - Size: 101
#   - Coverage: 1.3854595336076818e-07
#   - QD Score: 12005073787.702944
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.188621e+08
# > 107 itrs completed after 8599.92s
#   - Size: 102
#   - Coverage: 1.3991769547325102e-07
#   - QD Score: 11983077424.274496
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.174812e+08
# > 108 itrs completed after 8682.45s
#   - Size: 102
#   - Coverage: 1.3991769547325102e-07
#   - QD Score: 11928317364.138203
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.169443e+08
# > 109 itrs completed after 8762.62s
#   - Size: 102
#   - Coverage: 1.3991769547325102e-07
#   - QD Score: 11913756255.300522
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.168015e+08
# > 110 itrs completed after 8843.31s
#   - Size: 102
#   - Coverage: 1.3991769547325102e-07
#   - QD Score: 12141794329.35036
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.190372e+08
# > 111 itrs completed after 8924.81s
#   - Size: 102
#   - Coverage: 1.3991769547325102e-07
#   - QD Score: 11815805890.522163
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.158412e+08
# > 112 itrs completed after 9010.23s
#   - Size: 103
#   - Coverage: 1.4128943758573388e-07
#   - QD Score: 12306641191.49041
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.194820e+08
# > 113 itrs completed after 9090.63s
#   - Size: 104
#   - Coverage: 1.4266117969821675e-07
#   - QD Score: 12799933240.48509
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.230763e+08
# > 114 itrs completed after 9173.20s
#   - Size: 105
#   - Coverage: 1.4403292181069958e-07
#   - QD Score: 12800830011.414799
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.219127e+08
# > 115 itrs completed after 9254.69s
#   - Size: 105
#   - Coverage: 1.4403292181069958e-07
#   - QD Score: 13323460507.602547
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.268901e+08
# > 116 itrs completed after 9334.92s
#   - Size: 105
#   - Coverage: 1.4403292181069958e-07
#   - QD Score: 13434117737.528444
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.279440e+08
# > 117 itrs completed after 9408.00s
#   - Size: 105
#   - Coverage: 1.4403292181069958e-07
#   - QD Score: 13382186139.38286
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.274494e+08
# > 118 itrs completed after 9492.48s
#   - Size: 107
#   - Coverage: 1.4677640603566528e-07
#   - QD Score: 12994701451.91709
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.214458e+08
# > 119 itrs completed after 9571.15s
#   - Size: 108
#   - Coverage: 1.4814814814814815e-07
#   - QD Score: 12952654239.623884
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.199320e+08
# > 120 itrs completed after 9659.38s
#   - Size: 108
#   - Coverage: 1.4814814814814815e-07
#   - QD Score: 13023909662.322063
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.205918e+08
# > 121 itrs completed after 9742.93s
#   - Size: 109
#   - Coverage: 1.49519890260631e-07
#   - QD Score: 13173351686.837122
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.208564e+08
# > 122 itrs completed after 9828.52s
#   - Size: 109
#   - Coverage: 1.49519890260631e-07
#   - QD Score: 13029417070.081438
#   - Max Obj: 8.245410e+09
#   - Mean Obj: 1.195359e+08
# > 123 itrs completed after 9907.15s
#   - Size: 111
#   - Coverage: 1.522633744855967e-07
# ...
#   - Mean Obj: 3.632045e+08
# > 410 itrs completed after 33789.94s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 71671735363.46713
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.713561e+08
# > 411 itrs completed after 33868.78s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 72081163685.08946
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.734775e+08
# > 412 itrs completed after 33947.96s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 71775010940.58418
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.718912e+08
# > 413 itrs completed after 34025.81s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 71639101079.01013
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.711871e+08
# > 414 itrs completed after 34103.24s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 70259034775.58206
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.640364e+08
# > 415 itrs completed after 34179.57s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 71252709408.26602
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.691850e+08
# > 416 itrs completed after 34258.65s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 72521619203.91592
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.757597e+08
# > 417 itrs completed after 34345.83s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 69493182030.24753
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.600683e+08
# > 418 itrs completed after 34427.25s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 71315075467.32
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.695082e+08
# > 419 itrs completed after 34506.32s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 71299315543.41093
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.694265e+08
# > 420 itrs completed after 34584.52s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 71701259073.81496
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.715091e+08
# > 421 itrs completed after 34658.30s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 70125721089.43898
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.633457e+08
# > 422 itrs completed after 34737.39s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 71145693467.41818
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.686305e+08
# > 423 itrs completed after 34816.78s
#   - Size: 193
#   - Coverage: 2.647462277091907e-07
#   - QD Score: 68339047978.97825
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.540883e+08
# > 424 itrs completed after 34897.22s
#   - Size: 194
#   - Coverage: 2.661179698216735e-07
#   - QD Score: 68052325759.56964
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.507852e+08
# > 425 itrs completed after 34969.54s
#   - Size: 194
#   - Coverage: 2.661179698216735e-07
#   - QD Score: 67347175477.72717
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.471504e+08
# > 426 itrs completed after 35050.45s
#   - Size: 194
#   - Coverage: 2.661179698216735e-07
#   - QD Score: 70489169169.14368
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.633462e+08
# > 427 itrs completed after 35131.16s
#   - Size: 194
#   - Coverage: 2.661179698216735e-07
#   - QD Score: 71121809745.11716
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.666073e+08
# > 428 itrs completed after 35217.16s
#   - Size: 194
#   - Coverage: 2.661179698216735e-07
#   - QD Score: 71686954745.06073
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.695204e+08
# > 429 itrs completed after 35295.71s
#   - Size: 194
#   - Coverage: 2.661179698216735e-07
#   - QD Score: 74429641194.37965
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.836579e+08
# > 430 itrs completed after 35374.69s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 72618862520.4665
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.724044e+08
# > 431 itrs completed after 35465.00s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 73605524882.75223
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.774642e+08
# > 432 itrs completed after 35543.21s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 67803788897.156494
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.477117e+08
# > 433 itrs completed after 35622.39s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 69301335516.81602
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.553915e+08
# > 434 itrs completed after 35695.01s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 70746742576.2873
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.628038e+08
# > 435 itrs completed after 35768.59s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 69752757057.55525
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.577064e+08
# > 436 itrs completed after 35851.23s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 71256621323.15343
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.654186e+08
# > 437 itrs completed after 35932.90s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 69247264111.63521
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.551142e+08
# > 438 itrs completed after 36011.45s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 70197910950.21901
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.599893e+08
# > 439 itrs completed after 36095.13s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 72813646609.01378
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.734033e+08
# > 440 itrs completed after 36179.98s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 71090700450.61821
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.645677e+08
# > 441 itrs completed after 36259.36s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 75176179403.63809
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.855189e+08
# > 442 itrs completed after 36333.98s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 72488707901.88042
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.717370e+08
# > 443 itrs completed after 36417.52s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 76100268247.28003
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.902578e+08
# > 444 itrs completed after 36501.65s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 73658909351.9625
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.777380e+08
# > 445 itrs completed after 36577.04s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 73499737083.24461
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.769217e+08
# > 446 itrs completed after 36654.61s
#   - Size: 195
#   - Coverage: 2.6748971193415635e-07
#   - QD Score: 75314252295.09946
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.862269e+08
# > 447 itrs completed after 36732.36s
#   - Size: 197
#   - Coverage: 2.702331961591221e-07
#   - QD Score: 75228349379.77245
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.818698e+08
# > 448 itrs completed after 36810.16s
#   - Size: 197
#   - Coverage: 2.702331961591221e-07
#   - QD Score: 74869191727.04727
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.800467e+08
# > 449 itrs completed after 36888.76s
#   - Size: 197
#   - Coverage: 2.702331961591221e-07
#   - QD Score: 72539441427.08678
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.682205e+08
# > 450 itrs completed after 36962.30s
#   - Size: 197
#   - Coverage: 2.702331961591221e-07
#   - QD Score: 71970601788.4029
#   - Max Obj: 9.709249e+09
#   - Mean Obj: 3.653330e+08
# Iterations: 100%|██████████| 450/450 [10:15:55<00:00, 82.12s/it]

# %%
import pickle
print("{:e}".format(archive.best_elite['objective']))
#SI PROBLEME : ESSAYER AVEC RESULT ARCHIVE DE CMA MAE
serialized= {"params" : archive.best_elite['solution']}
with open('saved.pkl', 'wb') as f:  # open a text file
    pickle.dump(serialized, f) # serialize the list
# Out:
# 9.709249e+09
