# %%
import trainppo
import env_hiv

# %%
config = {
    "num_steps":200,
    "num_minibatches":4,
    "learning_rate":3e-4,
    "seed":123,
    "gamma":0.99,
    "gae_lambda":0.95,
    "update_epochs":4,
    "clip_coef":0.2,
    "ent_coef":0.01,
    "vf_coef":0.5,
    "max_grad_norm":0.5,
    'target_kl':None,
    "num_iterations":200

}
class Config:
    def __init__(self, config_dict):
        self.__dict__.update(config_dict)

config = Config(config)

agent = trainppo.ProjectAgent(config)
avg_returns = agent.train()
import matplotlib.pyplot as plt
plt.plot(avg_returns)
plt.show()
# Out:
#   4%|▍         | 9/200 [00:30<10:47,  3.39s/it, avg_returns=6.77e+5]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 24
#      21 config = Config(config)
#      23 agent = trainppo.ProjectAgent(config)
# ---> 24 avg_returns = agent.train()
#      25 import matplotlib.pyplot as plt
#      26 plt.plot(avg_returns)
#
# File ~/rl-class-assignment-Tordjx/src/trainppo.py:110, in ProjectAgent.train(self)
#     108 logprobs[step] = logprob
#     109 # TRY NOT TO MODIFY: execute the game and log data.
# --> 110 next_obs, reward, terminations, truncations, infos = self.env.step(action.cpu().numpy())
#     111 next_done = np.logical_or(terminations, truncations)
#     112 rewards[step] = torch.tensor(reward).to(self.device).view(-1)
#
# File ~/rl-class-assignment-Tordjx/src/env_hiv.py:232, in HIVPatient.step(self, a_index)
#     230 state = self.state()
# ...

# %%
import env_hiv
from train_a2c import *
import matplotlib.pyplot as plt
#env = gym.make("CartPole")
env = env_hiv.HIVPatient(domain_randomization=True)
pi = policyNetwork(env)
V  = valueNetwork(env)
config = {}
agent = a2c_agent(config, pi, V, maxiter = 200)
returns = agent.train(env,100)
plt.plot(returns)
# Out:
# 100%|██████████| 100/100 [05:12<00:00,  3.12s/it]

# %%
import matplotlib.pyplot as plt
plt.plot(returns)
