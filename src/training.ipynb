# %%
import train
import env_hiv

# %%
config = {
    "num_steps":200,
    "num_minibatches":4,
    "learning_rate":3e-4,
    "seed":123,
    "gamma":0.99,
    "gae_lambda":0.95,
    "update_epochs":4,
    "clip_coef":0.2,
    "ent_coef":0.01,
    "vf_coef":0.5,
    "max_grad_norm":0.5,
    'target_kl':None,
    "num_iterations":5000

}
class Config:
    def __init__(self, config_dict):
        self.__dict__.update(config_dict)

config = Config(config)

agent = train.ProjectAgent(config)
avg_returns = agent.train()
import matplotlib.pyplot as plt
plt.plot(avg_returns)
plt.show()
# Out:
#   0%|          | 3/5000 [00:11<5:20:35,  3.85s/it, avg_returns=6.18e+5]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 24
#      21 config = Config(config)
#      23 agent = train.ProjectAgent(config)
# ---> 24 avg_returns = agent.train()
#      25 import matplotlib.pyplot as plt
#      26 plt.plot(avg_returns)
#
# File ~/rl-class-assignment-Tordjx/src/train.py:110, in ProjectAgent.train(self)
#     108 logprobs[step] = logprob
#     109 # TRY NOT TO MODIFY: execute the game and log data.
# --> 110 next_obs, reward, terminations, truncations, infos = self.env.step(action.cpu().numpy())
#     111 next_done = np.logical_or(terminations, truncations)
#     112 rewards[step] = torch.tensor(reward).to(self.device).view(-1)
#
# File ~/rl-class-assignment-Tordjx/src/env_hiv.py:232, in HIVPatient.step(self, a_index)
#     230 state = self.state()
#     231 action = self.action_set[a_index]
# --> 232 state2 = self.transition(state, action, 5)
#     233 rew = self.reward(state, action, state2)
#     234 if self.clipping:
#
# File ~/rl-class-assignment-Tordjx/src/env_hiv.py:213, in HIVPatient.transition(self, state, action, duration)
#     211 nb_steps = int(duration // 1e-3)
#     212 for i in range(nb_steps):
# --> 213     der = self.der(state0, action)
#     214     state1 = state0 + der * 1e-3
#     216     # np.clip(state1, self.lower, self.upper, out=state1)
#
# File ~/rl-class-assignment-Tordjx/src/env_hiv.py:201, in HIVPatient.der(self, state, action)
#     185 T2stardot = (
#     186     self.k2 * (1 - self.f * eps1) * V * T2
#     187     - self.delta * T2star
#     188     - self.m2 * E * T2star
#     189 )
#     190 Vdot = (
#     191     self.NT * self.delta * (1 - eps2) * (T1star + T2star)
#     192     - self.c * V
#    (...)
#     197     * V
#     198 )
#     199 Edot = (
#     200     self.lambdaE
# --> 201     + self.bE * (T1star + T2star) * E / (T1star + T2star + self.Kb)
#     202     - self.dE * (T1star + T2star) * E / (T1star + T2star + self.Kd)
#     203     - self.deltaE * E
#     204 )
#     205 return np.array([T1dot, T1stardot, T2dot, T2stardot, Vdot, Edot])
#
# KeyboardInterrupt:

# %%
from train_a2c import *
import matplotlib.pyplot as plt
#env = gym.make("CartPole")
env = env_hiv.HIVPatient()
pi = policyNetwork(env)
V  = valueNetwork(env)
config = {}
agent = a2c_agent(config, pi, V, maxiter = 200)
returns = agent.train(env,10)
plt.plot(returns)
# Out:
# 100%|██████████| 10/10 [00:31<00:00,  3.11s/it]

# %%
import matplotlib.pyplot as plt
plt.plot(returns)
